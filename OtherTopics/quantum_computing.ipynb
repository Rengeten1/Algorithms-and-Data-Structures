# %% [markdown]
# # What is Quantum Computing?
#
# Quantum computing is a field of computing that leverages the principles of quantum mechanics to process information. Unlike classical computers that use bits (0s and 1s) to represent data, quantum computers use quantum bits or qubits, which can exist in multiple states simultaneously due to superposition. This allows quantum computers to perform complex calculations at speeds unattainable by classical computers for certain problems.

# %% [markdown]
# # What is a Qubit?
#
# A qubit, or quantum bit, is the fundamental unit of quantum information. Unlike a classical bit that can be either 0 or 1, a qubit can exist in a superposition of both states simultaneously, represented as |ψ⟩ = α|0⟩ + β|1⟩, where α and β are complex numbers that determine the probabilities of measuring the qubit in either state. This property allows quantum computers to perform certain computations more efficiently than classical computers.

# %% [markdown]
# # What is Grover's Algorithm?
# __What is Grover’s algorithm? Provide a brief explanation of the algorithm and discuss its speedup compared to a traditional algorithm. Use the Big $O$ notation in your explanation.__
# Grover's algorithm is a quantum algorithm designed for searching an unsorted database or an unstructured list. It provides a quadratic speedup compared to classical search algorithms. In a classical search, finding a specific item in an unsorted list of N items requires O(N) time in the worst case, as each item may need to be checked. Grover's algorithm, on the other hand, can find the desired item in O(√N) time by utilizing quantum superposition and interference.

# %% [markdown]
# # What is Shor's algorithm?
# __What is Shor’s algorithm? Provide a brief explanation of the algorithm and discuss its speedup compared to a traditional algorithm and also how it is better than Grover's algorithm. Use the Big $O$ notation in your explanation.__
# Shor's algorithm is a quantum algorithm for integer factorization, which means it can efficiently find the prime factors of a composite number. The algorithm is significant because it can break widely used cryptographic systems, such as RSA, which rely on the difficulty of factoring large numbers. Shor's algorithm runs in polynomial time, specifically O((log N)^3), where N is the number to be factored. This is exponentially faster than the best-known classical algorithms for factoring, which run in sub-exponential time, such as the general number field sieve with a time complexity of O(exp((64/9)^(1/3) * (log N)^(1/3) * (log log N)^(2/3))).
